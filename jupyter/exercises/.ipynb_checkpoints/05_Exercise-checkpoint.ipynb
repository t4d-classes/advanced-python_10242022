# %% [markdown]
# # Exercise #5

# %% [markdown]
# Step 1. Load the cities (not the swapped version) CSV file created in exercise 4. Use only the city for the index. You can modify the cities.csv file with Excel to only have the first 10 rows.

# %%
# Step 1 Solution

import pandas as pd

def clean_up_city(x):
    return x.split("[")[0].strip()

cities = pd.read_csv("cities.csv")
cities[0:10].to_csv("cities_top10.csv")
cities = pd.read_csv("cities_top10.csv", index_col=0)
cities["City"] = cities["City"].apply(clean_up_city)
cities.to_csv("cities_top10.csv", index=False)
cities = pd.read_csv("cities_top10.csv", index_col=0)
cities
# Out:
#                         State  2010 Actual  2020 Estimate  \
# City
# New York City       New York     8175133.0      8253213.0
# Los Angeles       California     3792621.0      3970219.0
# Chicago             Illinois     2695598.0      2677643.0
# Houston                Texas     2100263.0      2316120.0
# Philadelphia    Pennsylvania     1526006.0      1578487.0
# Phoenix              Arizona     1445632.0      1708127.0
# San Antonio            Texas     1327407.0      1567118.0
# San Diego         California     1307402.0      1422420.0
# Dallas                 Texas     1197816.0      1343266.0
# San Jose          California      945942.0      1013616.0
#
#                2016 Land Area (sq mi)  Population Change  \
# City
# New York City                   301.5           0.955091
# Los Angeles                     468.7           4.682725
# Chicago                         227.3          -0.666086
# Houston                         637.5          10.277618
# Philadelphia                    134.2           3.439108
# Phoenix                         517.6          18.157802
# San Antonio                     461.0          18.058591
# San Diego                       325.2           8.797447
# Dallas                          340.9          12.142933
# San Jose                        177.5           7.154138
#
#                Population Density 2010  Population Density 2020
# City
# New York City             27114.868988             27373.840796
# Los Angeles                8091.787924              8470.704075
# Chicago                   11859.208095             11780.215574
# Houston                    3294.530196              3633.129412
# Philadelphia              11371.132638             11762.198212
# Phoenix                    2792.952087              3300.090804
# San Antonio                2879.407809              3399.388286
# San Diego                  4020.301353              4373.985240
# Dallas                     3513.687298              3940.352009
# San Jose                   5329.250704              5710.512676

# %% [markdown]
# Step 2. Use head to display the first three rows.

# %%
# Step 2 Solution
cities.head(3)
# Out:
#                       State  2010 Actual  2020 Estimate  \
# City
# New York City     New York     8175133.0      8253213.0
# Los Angeles     California     3792621.0      3970219.0
# Chicago           Illinois     2695598.0      2677643.0
#
#                2016 Land Area (sq mi)  Population Change  \
# City
# New York City                   301.5           0.955091
# Los Angeles                     468.7           4.682725
# Chicago                         227.3          -0.666086
#
#                Population Density 2010  Population Density 2020
# City
# New York City             27114.868988             27373.840796
# Los Angeles                8091.787924              8470.704075
# Chicago                   11859.208095             11780.215574

# %% [markdown]
# Step 3. Use tail to display the last three rows.

# %%
# Step 3 Solution
cities.tail(3)
# Out:
#                   State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# San Diego   California     1307402.0      1422420.0                   325.2
# Dallas           Texas     1197816.0      1343266.0                   340.9
# San Jose    California      945942.0      1013616.0                   177.5
#
#            Population Change  Population Density 2010  Population Density 2020
# City
# San Diego           8.797447              4020.301353              4373.985240
# Dallas             12.142933              3513.687298              3940.352009
# San Jose            7.154138              5329.250704              5710.512676

# %% [markdown]
# Step 4. Display the row for Phoenix using the label. Hint: take a look at "loc" attribute.

# %%
# Step 4 Solution

cities.loc[ ["Phoenix"] ]
# Out:
#              State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Phoenix   Arizona     1445632.0      1708127.0                   517.6
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Phoenix          18.157802              2792.952087              3300.090804

# %% [markdown]
# Step 5. Display the row for Phoenix using the row index. Hint: take a look at "iloc" attribute.

# %%
# Step 5 Solution

cities.index.get_loc("Phoenix")

cities.iloc[cities.index.get_loc("Phoenix")]
# Out:
# State                         Arizona
# 2010 Actual                  1445632.0
# 2020 Estimate                1708127.0
# 2016 Land Area (sq mi)           517.6
# Population Change            18.157802
# Population Density 2010    2792.952087
# Population Density 2020    3300.090804
# Name: Phoenix, dtype: object

# %% [markdown]
# Step 6. How many cities experienced negative growth from 2010 to 2020?

# %%
# Step 6 Solution

cities[cities["Population Change"] < 0].count()
# Out:
# State                      1
# 2010 Actual                1
# 2020 Estimate              1
# 2016 Land Area (sq mi)     1
# Population Change          1
# Population Density 2010    1
# Population Density 2020    1
# dtype: int64

# %% [markdown]
# Step 7. Display Chicago to Houston using a range of labels.

# %%
# Step 7 Solution

cities[ "Chicago":"Houston" ]
# Out:
#               State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Chicago   Illinois     2695598.0      2677643.0                   227.3
# Houston      Texas     2100263.0      2316120.0                   637.5
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Chicago          -0.666086             11859.208095             11780.215574
# Houston          10.277618              3294.530196              3633.129412

# %% [markdown]
# Step 8. Display Chicago to Houston using a range of indexes. Hint: take a look at "iloc" attribute.

# %%
# Step 8 Solution
cities.iloc[2:4]
# Out:
#               State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Chicago   Illinois     2695598.0      2677643.0                   227.3
# Houston      Texas     2100263.0      2316120.0                   637.5
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Chicago          -0.666086             11859.208095             11780.215574
# Houston          10.277618              3294.530196              3633.129412

# %% [markdown]
# Step 9. Display descriptive statistics for the data frame.

# %%
# Step 9 Solution
cities.describe()
# Out:
#         2010 Actual  2020 Estimate  2016 Land Area (sq mi)  Population Change  \
# count  1.000000e+01   1.000000e+01               10.000000          10.000000
# mean   2.451382e+06   2.585023e+06              359.140000           8.299937
# std    2.186342e+06   2.168183e+06              160.122378           6.529397
# min    9.459420e+05   1.013616e+06              134.200000          -0.666086
# 25%    1.312403e+06   1.458594e+06              245.850000           3.750012
# 50%    1.485819e+06   1.643307e+06              333.050000           7.975793
# 75%    2.546764e+06   2.587262e+06              466.775000          11.676605
# max    8.175133e+06   8.253213e+06              637.500000          18.157802
#
#        Population Density 2010  Population Density 2020
# count                10.000000                10.000000
# mean               8026.712709              8374.441708
# std                7529.281295              7452.100220
# min                2792.952087              3300.090804
# 25%                3349.319472              3709.935061
# 50%                4674.776029              5042.248958
# 75%               10551.296459             10939.324677
# max               27114.868988             27373.840796

# %% [markdown]
# Step 10. Use a pie chart to show the 2020 estimated population of the first 10 cities relative to the other cities in the data frame.

# %%
# Step 10 Solution

from matplotlib import pyplot as plt
# %matplotlib inline

fig_1 = plt.figure(1, figsize=(10, 10), facecolor="white")

ax1 = fig_1.add_subplot(111)

ax1.pie(
  cities["2020 Estimate"].values,
  labels=cities.index.values,
  autopct='%1.1f%%',
)

ax1.axis('equal')


plt.show()
